# %% [markdown]
# # Approach
#
# * Firstly a convolutional neural network is used to segment the image, using the bounding boxes directly as a mask.
# * Secondly connected components is used to separate multiple areas of predicted pneumonia.
# * Finally a bounding box is simply drawn around every connected component.
#
# # Network
#
# * The network consists of a number of residual blocks with convolutions and downsampling blocks with max pooling.
# * At the end of the network a single upsampling layer converts the output to the same shape as the input.
#
# As the input to the network is 256 by 256 (instead of the original 1024 by 1024) and the network downsamples a number of times without any meaningful upsampling (the final upsampling is just to match in 256 by 256 mask) the final prediction is very crude. If the network downsamples 4 times the final bounding boxes can only change with at least 16 pixels.

# %%
import os
import csv
import random
import pydicom
import numpy as np
import pandas as pd
from skimage import measure
from skimage.transform import resize

import tensorflow as tf
from tensorflow import keras

from matplotlib import pyplot as plt

# %% [markdown]
# # Load pneumonia locations
#
# Table contains [filename : pneumonia location] pairs per row.
# * If a filename contains multiple pneumonia, the table contains multiple rows with the same filename but different pneumonia locations.
# * If a filename contains no pneumonia it contains a single row with an empty pneumonia location.
#
# The code below loads the table and transforms it into a dictionary.
# * The dictionary uses the filename as key and a list of pneumonia locations in that filename as value.
# * If a filename is not present in the dictionary it means that it contains no pneumonia.

# %%
# empty dictionary
pneumonia_locations = {}
# load table
with open(os.path.join('./input/stage_1_train_labels.csv'), mode='r') as infile:
    # open reader
    reader = csv.reader(infile)
    # skip header
    next(reader, None)
    # loop through rows
    for rows in reader:
        # retrieve information
        filename = rows[0]
        location = rows[1:5]
        pneumonia = rows[5]
        # if row contains pneumonia add label to dictionary
        # which contains a list of pneumonia locations per filename
        if pneumonia == '1':
            # convert string to float to int
            location = [int(float(i)) for i in location]
            # save pneumonia location in dictionary
            if filename in pneumonia_locations:
                pneumonia_locations[filename].append(location)
            else:
                pneumonia_locations[filename] = [location]

# %% [markdown]
# # Load filenames

# %%
# load and shuffle filenames
folder = './input/rsna-pneumonia-detection-challenge/stage_1_train_images'
filenames = os.listdir(folder)
random.shuffle(filenames)
# split into train and validation filenames
n_valid_samples = 2568
train_filenames = filenames[n_valid_samples:]
valid_filenames = filenames[:n_valid_samples]
print('n train samples', len(train_filenames))
print('n valid samples', len(valid_filenames))
n_train_samples = len(filenames) - n_valid_samples
# Out:
# n train samples 23116
# n valid samples 2568

# %% [markdown]
# # Exploration

# %%
print('Total train images:',len(filenames))
print('Images with pneumonia:', len(pneumonia_locations))

ns = [len(value) for value in pneumonia_locations.values()]
plt.figure()
plt.hist(ns)
plt.xlabel('Pneumonia per image')
plt.xticks(range(1, np.max(ns)+1))
plt.show()

heatmap = np.zeros((1024, 1024))
ws = []
hs = []
for values in pneumonia_locations.values():
    for value in values:
        x, y, w, h = value
        heatmap[y:y+h, x:x+w] += 1
        ws.append(w)
        hs.append(h)
plt.figure()
plt.title('Pneumonia location heatmap')
plt.imshow(heatmap)
plt.figure()
plt.title('Pneumonia height lengths')
plt.hist(hs, bins=np.linspace(0,1000,50))
plt.show()
plt.figure()
plt.title('Pneumonia width lengths')
plt.hist(ws, bins=np.linspace(0,1000,50))
plt.show()
print('Minimum pneumonia height:', np.min(hs))
print('Minimum pneumonia width: ', np.min(ws))
# Out:
# Total train images: 25684
# Images with pneumonia: 5659
# Minimum pneumonia height: 45
# Minimum pneumonia width:  40

# %% [markdown]
#  # Data generator
#
# The dataset is too large to fit into memory, so we need to create a generator that loads data on the fly.
#
# * The generator takes in some filenames, batch_size and other parameters.
#
# * The generator outputs a random batch of numpy images and numpy masks.

# %%
class generator(keras.utils.Sequence):
    
    def __init__(self, folder, filenames, pneumonia_locations=None, batch_size=32, image_size=256, shuffle=True, augment=False, predict=False):
        self.folder = folder
        self.filenames = filenames
        self.pneumonia_locations = pneumonia_locations
        self.batch_size = batch_size
        self.image_size = image_size
        self.shuffle = shuffle
        self.augment = augment
        self.predict = predict
        self.on_epoch_end()
        
    def __load__(self, filename):
        # load dicom file as numpy array
        img = pydicom.dcmread(os.path.join(self.folder, filename)).pixel_array
        # create empty mask
        msk = np.zeros(img.shape)
        # get filename without extension
        filename = filename.split('.')[0]
        # if image contains pneumonia
        if filename in pneumonia_locations:
            # loop through pneumonia
            for location in pneumonia_locations[filename]:
                # add 1's at the location of the pneumonia
                x, y, w, h = location
                msk[y:y+h, x:x+w] = 1
        # if augment then horizontal flip half the time
        if self.augment and random.random() > 0.6:
            img = np.fliplr(img)
            msk = np.fliplr(msk)
        # resize both image and mask
        img = resize(img, (self.image_size, self.image_size), mode='reflect')
        msk = resize(msk, (self.image_size, self.image_size), mode='reflect') > 0.55 #0.45
        # add trailing channel dimension
        img = np.expand_dims(img, -1)
        msk = np.expand_dims(msk, -1)
        return img, msk
    
    def __loadpredict__(self, filename):
        # load dicom file as numpy array
        img = pydicom.dcmread(os.path.join(self.folder, filename)).pixel_array
        # resize image
        img = resize(img, (self.image_size, self.image_size), mode='reflect')
        # add trailing channel dimension
        img = np.expand_dims(img, -1)
        return img
        
    def __getitem__(self, index):
        # select batch
        filenames = self.filenames[index*self.batch_size:(index+1)*self.batch_size]
        # predict mode: return images and filenames
        if self.predict:
            # load files
            imgs = [self.__loadpredict__(filename) for filename in filenames]
            # create numpy batch
            imgs = np.array(imgs)
            return imgs, filenames
        # train mode: return images and masks
        else:
            # load files
            items = [self.__load__(filename) for filename in filenames]
            # unzip images and masks
            imgs, msks = zip(*items)
            # create numpy batch
            imgs = np.array(imgs)
            msks = np.array(msks)
            return imgs, msks
        
    def on_epoch_end(self):
        if self.shuffle:
            random.shuffle(self.filenames)
        
    def __len__(self):
        if self.predict:
            # return everything
            return int(np.ceil(len(self.filenames) / self.batch_size))
        else:
            # return full batches only
            return int(len(self.filenames) / self.batch_size)

# %% [markdown]
# # Network

# %%
def create_downsample(channels, inputs):
    x = keras.layers.BatchNormalization(momentum=0.9)(inputs)
    x = keras.layers.LeakyReLU(0)(x)
    x = keras.layers.Dropout(0.2)(x)
    x = keras.layers.Conv2D(channels, 1, padding='same', use_bias=False)(x)
    x = keras.layers.MaxPool2D((2, 2))(x)
    return x

def create_resblock(channels, inputs):
    x = keras.layers.BatchNormalization(momentum=0.9)(inputs)
    x = keras.layers.LeakyReLU(0)(x)
    x = keras.layers.Conv2D(channels, 3, padding='same', use_bias=False)(x)
    x = keras.layers.BatchNormalization(momentum=0.9)(x)
    x = keras.layers.LeakyReLU(0)(x)
    x = keras.layers.Dropout(0.2)(x)
    x = keras.layers.Conv2D(channels, 3, padding='same', use_bias=False)(x)
    return keras.layers.add([x, inputs])

def create_network(input_size, channels, n_blocks=2, depth=4):
    # input
    inputs = keras.Input(shape=(input_size, input_size, 1))
    x = keras.layers.Conv2D(channels, 3, padding='same', use_bias=False)(inputs)
    # residual blocks
    for d in range(depth):
        channels = channels * 2
        x = create_downsample(channels, x)
        for b in range(n_blocks):
            x = create_resblock(channels, x)
    # output
    x = keras.layers.BatchNormalization(momentum=0.9)(x)
    x = keras.layers.LeakyReLU(0)(x)
    x = keras.layers.Conv2D(1, 1, activation='sigmoid')(x)
    outputs = keras.layers.UpSampling2D(2**depth)(x)
    model = keras.Model(inputs=inputs, outputs=outputs)
    return model

# %% [markdown]
# # Train network

# %%
# define iou or jaccard loss function
def iou_loss(y_true, y_pred):
    y_true = tf.reshape(y_true, [-1])
    y_pred = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true * y_pred)
    score = (intersection + 1.) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection + 1.)
    return 1 - score

# combine bce loss and iou loss
def iou_bce_loss(y_true, y_pred):
    return 0.5 * keras.losses.binary_crossentropy(y_true, y_pred) + 0.5 * iou_loss(y_true, y_pred)

# mean iou as a metric
def mean_iou(y_true, y_pred):
    y_pred = tf.round(y_pred)
    intersect = tf.reduce_sum(y_true * y_pred, axis=[1, 2, 3])
    union = tf.reduce_sum(y_true, axis=[1, 2, 3]) + tf.reduce_sum(y_pred, axis=[1, 2, 3])
    smooth = tf.ones(tf.shape(intersect))
    return tf.reduce_mean((intersect + smooth) / (union - intersect + smooth))

# create network and compiler
model = create_network(input_size=256, channels=32, n_blocks=2, depth=3)
#print(model.summary())
#print("LAYERS")
#print(model.layers)
print("NUM OF LAYERS")
print(len(model.layers))


model.compile(optimizer='adam',
              loss=iou_bce_loss,
              metrics=['accuracy', mean_iou])
'''
model.compile(optimizer=tf.keras.optimizers.Adam(lr = 0.1),
              loss=iou_loss,
              metrics=['accuracy', mean_iou])
'''
# cosine learning rate annealing
def cosine_annealing(x):
    lr = 0.001
    epochs = 100
    return lr*(np.cos(np.pi*x/epochs)+1.)/2
learning_rate = tf.keras.callbacks.LearningRateScheduler(cosine_annealing)
#learning_rate = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.1, verbose=1, patience = 10, min_lr = 0.0001, mode = 'auto')

# create train and validation generators
folder = './input/rsna-pneumonia-detection-challenge/stage_1_train_images'
train_gen = generator(folder, train_filenames, pneumonia_locations, batch_size=32, image_size=256, shuffle=True, augment=True, predict=False)
valid_gen = generator(folder, valid_filenames, pneumonia_locations, batch_size=32, image_size=256, shuffle=False, predict=False)

history = model.fit_generator(train_gen, validation_data=valid_gen, callbacks=[learning_rate], epochs=100, shuffle=True)
#history = model.fit_generator(train_gen, validation_data=valid_gen, epochs=10, shuffle=True)
# Out:
# NUM OF LAYERS
# 69
# Epoch 1/100
# 722/722 [==============================] - 898s 1s/step - loss: 0.4932 - acc: 0.9621 - mean_iou: 0.5390 - val_loss: 0.6436 - val_acc: 0.8476 - val_mean_iou: 0.1327
# Epoch 2/100
# 722/722 [==============================] - 748s 1s/step - loss: 0.4506 - acc: 0.9666 - mean_iou: 0.5874 - val_loss: 0.5310 - val_acc: 0.9170 - val_mean_iou: 0.3438
# Epoch 3/100
# 722/722 [==============================] - 734s 1s/step - loss: 0.4348 - acc: 0.9683 - mean_iou: 0.6221 - val_loss: 0.4512 - val_acc: 0.9516 - val_mean_iou: 0.5008
# Epoch 4/100
# 722/722 [==============================] - 736s 1s/step - loss: 0.4197 - acc: 0.9700 - mean_iou: 0.6470 - val_loss: 0.4306 - val_acc: 0.9631 - val_mean_iou: 0.6102
# Epoch 5/100
# 722/722 [==============================] - 745s 1s/step - loss: 0.4123 - acc: 0.9708 - mean_iou: 0.6608 - val_loss: 0.4385 - val_acc: 0.9677 - val_mean_iou: 0.5887
# Epoch 6/100
# 722/722 [==============================] - 730s 1s/step - loss: 0.4064 - acc: 0.9717 - mean_iou: 0.6732 - val_loss: 0.4371 - val_acc: 0.9710 - val_mean_iou: 0.6424
# Epoch 7/100
# 722/722 [==============================] - 728s 1s/step - loss: 0.4020 - acc: 0.9717 - mean_iou: 0.6766 - val_loss: 0.4198 - val_acc: 0.9753 - val_mean_iou: 0.7275
# Epoch 8/100
# 722/722 [==============================] - 727s 1s/step - loss: 0.3995 - acc: 0.9722 - mean_iou: 0.6827 - val_loss: 0.4030 - val_acc: 0.9719 - val_mean_iou: 0.6774
# Epoch 9/100
# 722/722 [==============================] - 728s 1s/step - loss: 0.3982 - acc: 0.9721 - mean_iou: 0.6857 - val_loss: 0.4092 - val_acc: 0.9758 - val_mean_iou: 0.7275
# Epoch 10/100
# 722/722 [==============================] - 745s 1s/step - loss: 0.3944 - acc: 0.9726 - mean_iou: 0.6910 - val_loss: 0.4289 - val_acc: 0.9735 - val_mean_iou: 0.6897
# Epoch 11/100
# 722/722 [==============================] - 740s 1s/step - loss: 0.3923 - acc: 0.9728 - mean_iou: 0.6960 - val_loss: 0.4999 - val_acc: 0.9746 - val_mean_iou: 0.7542
# Epoch 12/100
# 722/722 [==============================] - 742s 1s/step - loss: 0.3915 - acc: 0.9729 - mean_iou: 0.7021 - val_loss: 0.4151 - val_acc: 0.9736 - val_mean_iou: 0.7104
# Epoch 13/100
# 722/722 [==============================] - 869s 1s/step - loss: 0.3916 - acc: 0.9731 - mean_iou: 0.6991 - val_loss: 0.3955 - val_acc: 0.9720 - val_mean_iou: 0.6849
# Epoch 14/100
# 722/722 [==============================] - 880s 1s/step - loss: 0.3889 - acc: 0.9735 - mean_iou: 0.7036 - val_loss: 0.4087 - val_acc: 0.9723 - val_mean_iou: 0.7078
# Epoch 15/100
# 722/722 [==============================] - 723s 1s/step - loss: 0.3880 - acc: 0.9733 - mean_iou: 0.7016 - val_loss: 0.4085 - val_acc: 0.9720 - val_mean_iou: 0.7094
# Epoch 16/100
# 722/722 [==============================] - 733s 1s/step - loss: 0.3872 - acc: 0.9735 - mean_iou: 0.7061 - val_loss: 0.3983 - val_acc: 0.9736 - val_mean_iou: 0.7190
# Epoch 17/100
# 722/722 [==============================] - 727s 1s/step - loss: 0.3845 - acc: 0.9736 - mean_iou: 0.7077 - val_loss: 0.4062 - val_acc: 0.9741 - val_mean_iou: 0.7051
# Epoch 18/100
# 722/722 [==============================] - 852s 1s/step - loss: 0.3826 - acc: 0.9740 - mean_iou: 0.7105 - val_loss: 0.3951 - val_acc: 0.9721 - val_mean_iou: 0.7047
# Epoch 19/100
# 722/722 [==============================] - 863s 1s/step - loss: 0.3824 - acc: 0.9742 - mean_iou: 0.7096 - val_loss: 0.3981 - val_acc: 0.9736 - val_mean_iou: 0.7150
# Epoch 20/100
# 722/722 [==============================] - 730s 1s/step - loss: 0.3822 - acc: 0.9741 - mean_iou: 0.7110 - val_loss: 0.4096 - val_acc: 0.9739 - val_mean_iou: 0.7178
# Epoch 21/100
# 722/722 [==============================] - 826s 1s/step - loss: 0.3809 - acc: 0.9740 - mean_iou: 0.7101 - val_loss: 0.4854 - val_acc: 0.9753 - val_mean_iou: 0.7638
# Epoch 22/100
# 722/722 [==============================] - 764s 1s/step - loss: 0.3795 - acc: 0.9742 - mean_iou: 0.7151 - val_loss: 0.4064 - val_acc: 0.9759 - val_mean_iou: 0.7433
# Epoch 23/100
# 722/722 [==============================] - 822s 1s/step - loss: 0.3801 - acc: 0.9740 - mean_iou: 0.7119 - val_loss: 0.4045 - val_acc: 0.9746 - val_mean_iou: 0.7288
# Epoch 24/100
# 722/722 [==============================] - 690s 956ms/step - loss: 0.3784 - acc: 0.9742 - mean_iou: 0.7124 - val_loss: 0.4001 - val_acc: 0.9709 - val_mean_iou: 0.6905
# Epoch 25/100
# 722/722 [==============================] - 688s 952ms/step - loss: 0.3777 - acc: 0.9745 - mean_iou: 0.7172 - val_loss: 0.3987 - val_acc: 0.9722 - val_mean_iou: 0.7114
# Epoch 26/100
# 722/722 [==============================] - 679s 940ms/step - loss: 0.3771 - acc: 0.9746 - mean_iou: 0.7168 - val_loss: 0.3959 - val_acc: 0.9732 - val_mean_iou: 0.7071
# Epoch 27/100
# 722/722 [==============================] - 806s 1s/step - loss: 0.3746 - acc: 0.9749 - mean_iou: 0.7202 - val_loss: 0.4258 - val_acc: 0.9747 - val_mean_iou: 0.7514
# Epoch 28/100
# 722/722 [==============================] - 695s 963ms/step - loss: 0.3741 - acc: 0.9750 - mean_iou: 0.7209 - val_loss: 0.4060 - val_acc: 0.9757 - val_mean_iou: 0.7456
# Epoch 29/100
# 722/722 [==============================] - 688s 953ms/step - loss: 0.3743 - acc: 0.9751 - mean_iou: 0.7228 - val_loss: 0.4065 - val_acc: 0.9738 - val_mean_iou: 0.7377
# Epoch 30/100
# 722/722 [==============================] - 697s 966ms/step - loss: 0.3721 - acc: 0.9751 - mean_iou: 0.7236 - val_loss: 0.3910 - val_acc: 0.9735 - val_mean_iou: 0.7227
# Epoch 31/100
# 722/722 [==============================] - 704s 976ms/step - loss: 0.3717 - acc: 0.9753 - mean_iou: 0.7244 - val_loss: 0.3962 - val_acc: 0.9737 - val_mean_iou: 0.7186
# Epoch 32/100
# 722/722 [==============================] - 814s 1s/step - loss: 0.3706 - acc: 0.9752 - mean_iou: 0.7269 - val_loss: 0.4047 - val_acc: 0.9754 - val_mean_iou: 0.7398
# Epoch 33/100
# 722/722 [==============================] - 689s 955ms/step - loss: 0.3694 - acc: 0.9755 - mean_iou: 0.7268 - val_loss: 0.3946 - val_acc: 0.9743 - val_mean_iou: 0.7352
# Epoch 34/100
# 722/722 [==============================] - 716s 991ms/step - loss: 0.3677 - acc: 0.9755 - mean_iou: 0.7268 - val_loss: 0.3939 - val_acc: 0.9742 - val_mean_iou: 0.7345
# Epoch 35/100
# 722/722 [==============================] - 820s 1s/step - loss: 0.3669 - acc: 0.9757 - mean_iou: 0.7286 - val_loss: 0.3890 - val_acc: 0.9734 - val_mean_iou: 0.7187
# Epoch 36/100
# 722/722 [==============================] - 714s 989ms/step - loss: 0.3656 - acc: 0.9758 - mean_iou: 0.7286 - val_loss: 0.3996 - val_acc: 0.9734 - val_mean_iou: 0.7154
# Epoch 37/100
# 722/722 [==============================] - 930s 1s/step - loss: 0.3652 - acc: 0.9758 - mean_iou: 0.7290 - val_loss: 0.3938 - val_acc: 0.9722 - val_mean_iou: 0.6971
# Epoch 38/100
# 722/722 [==============================] - 853s 1s/step - loss: 0.3663 - acc: 0.9759 - mean_iou: 0.7305 - val_loss: 0.4019 - val_acc: 0.9731 - val_mean_iou: 0.7123
# Epoch 39/100
# 722/722 [==============================] - 775s 1s/step - loss: 0.3641 - acc: 0.9763 - mean_iou: 0.7339 - val_loss: 0.3943 - val_acc: 0.9723 - val_mean_iou: 0.7152
# Epoch 40/100
# 722/722 [==============================] - 673s 932ms/step - loss: 0.3620 - acc: 0.9765 - mean_iou: 0.7382 - val_loss: 0.3974 - val_acc: 0.9748 - val_mean_iou: 0.7382
# Epoch 41/100
# 722/722 [==============================] - 660s 914ms/step - loss: 0.3607 - acc: 0.9765 - mean_iou: 0.7377 - val_loss: 0.3960 - val_acc: 0.9728 - val_mean_iou: 0.7161
# Epoch 42/100
# 722/722 [==============================] - 643s 891ms/step - loss: 0.3594 - acc: 0.9766 - mean_iou: 0.7363 - val_loss: 0.3986 - val_acc: 0.9732 - val_mean_iou: 0.7236
# Epoch 43/100
# 722/722 [==============================] - 649s 898ms/step - loss: 0.3593 - acc: 0.9769 - mean_iou: 0.7376 - val_loss: 0.3958 - val_acc: 0.9733 - val_mean_iou: 0.7288
# Epoch 44/100
# 722/722 [==============================] - 659s 913ms/step - loss: 0.3603 - acc: 0.9769 - mean_iou: 0.7366 - val_loss: 0.4552 - val_acc: 0.9763 - val_mean_iou: 0.7596
# Epoch 45/100
# 722/722 [==============================] - 674s 934ms/step - loss: 0.3568 - acc: 0.9770 - mean_iou: 0.7408 - val_loss: 0.3918 - val_acc: 0.9710 - val_mean_iou: 0.7001
# Epoch 46/100
# 722/722 [==============================] - 646s 895ms/step - loss: 0.3562 - acc: 0.9771 - mean_iou: 0.7415 - val_loss: 0.3955 - val_acc: 0.9713 - val_mean_iou: 0.6955
# Epoch 47/100
# 722/722 [==============================] - 839s 1s/step - loss: 0.3540 - acc: 0.9773 - mean_iou: 0.7435 - val_loss: 0.3950 - val_acc: 0.9730 - val_mean_iou: 0.7081
# Epoch 48/100
# 722/722 [==============================] - 698s 966ms/step - loss: 0.3548 - acc: 0.9775 - mean_iou: 0.7444 - val_loss: 0.3955 - val_acc: 0.9706 - val_mean_iou: 0.7033
# Epoch 49/100
# 722/722 [==============================] - 639s 885ms/step - loss: 0.3523 - acc: 0.9775 - mean_iou: 0.7452 - val_loss: 0.3951 - val_acc: 0.9707 - val_mean_iou: 0.6966
# Epoch 50/100
# 722/722 [==============================] - 616s 853ms/step - loss: 0.3507 - acc: 0.9777 - mean_iou: 0.7459 - val_loss: 0.3962 - val_acc: 0.9723 - val_mean_iou: 0.7063
# Epoch 51/100
# 722/722 [==============================] - 614s 850ms/step - loss: 0.3484 - acc: 0.9779 - mean_iou: 0.7465 - val_loss: 0.3959 - val_acc: 0.9715 - val_mean_iou: 0.7158
# Epoch 52/100
# 722/722 [==============================] - 749s 1s/step - loss: 0.3475 - acc: 0.9780 - mean_iou: 0.7481 - val_loss: 0.3991 - val_acc: 0.9687 - val_mean_iou: 0.6778
# Epoch 53/100
# 722/722 [==============================] - 745s 1s/step - loss: 0.3464 - acc: 0.9783 - mean_iou: 0.7495 - val_loss: 0.3949 - val_acc: 0.9710 - val_mean_iou: 0.6978
# Epoch 54/100
# 722/722 [==============================] - 628s 870ms/step - loss: 0.3466 - acc: 0.9783 - mean_iou: 0.7535 - val_loss: 0.3945 - val_acc: 0.9697 - val_mean_iou: 0.6968
# Epoch 55/100
# 722/722 [==============================] - 722s 1000ms/step - loss: 0.3444 - acc: 0.9784 - mean_iou: 0.7468 - val_loss: 0.3939 - val_acc: 0.9715 - val_mean_iou: 0.7126
# Epoch 56/100
# 722/722 [==============================] - 644s 892ms/step - loss: 0.3440 - acc: 0.9785 - mean_iou: 0.7493 - val_loss: 0.3987 - val_acc: 0.9670 - val_mean_iou: 0.6658
# Epoch 57/100
# 722/722 [==============================] - 651s 901ms/step - loss: 0.3414 - acc: 0.9788 - mean_iou: 0.7538 - val_loss: 0.3979 - val_acc: 0.9696 - val_mean_iou: 0.6801
# Epoch 58/100
# 722/722 [==============================] - 631s 873ms/step - loss: 0.3416 - acc: 0.9788 - mean_iou: 0.7524 - val_loss: 0.3971 - val_acc: 0.9686 - val_mean_iou: 0.6766
# Epoch 59/100
# 722/722 [==============================] - 637s 882ms/step - loss: 0.3404 - acc: 0.9790 - mean_iou: 0.7538 - val_loss: 0.3949 - val_acc: 0.9705 - val_mean_iou: 0.6907
# Epoch 60/100
# 722/722 [==============================] - 636s 881ms/step - loss: 0.3379 - acc: 0.9792 - mean_iou: 0.7562 - val_loss: 0.4002 - val_acc: 0.9674 - val_mean_iou: 0.6668
# Epoch 61/100
# 722/722 [==============================] - 644s 892ms/step - loss: 0.3383 - acc: 0.9792 - mean_iou: 0.7556 - val_loss: 0.4037 - val_acc: 0.9671 - val_mean_iou: 0.6718
# Epoch 62/100
# 722/722 [==============================] - 632s 875ms/step - loss: 0.3377 - acc: 0.9793 - mean_iou: 0.7557 - val_loss: 0.3997 - val_acc: 0.9687 - val_mean_iou: 0.6783
# Epoch 63/100
# 722/722 [==============================] - 638s 884ms/step - loss: 0.3347 - acc: 0.9797 - mean_iou: 0.7594 - val_loss: 0.4059 - val_acc: 0.9669 - val_mean_iou: 0.6601
# Epoch 64/100
# 722/722 [==============================] - 643s 891ms/step - loss: 0.3358 - acc: 0.9797 - mean_iou: 0.7575 - val_loss: 0.3987 - val_acc: 0.9695 - val_mean_iou: 0.6788
# Epoch 65/100
# 722/722 [==============================] - 629s 872ms/step - loss: 0.3311 - acc: 0.9798 - mean_iou: 0.7597 - val_loss: 0.4017 - val_acc: 0.9686 - val_mean_iou: 0.6789
# Epoch 66/100
# 722/722 [==============================] - 741s 1s/step - loss: 0.3307 - acc: 0.9799 - mean_iou: 0.7612 - val_loss: 0.4043 - val_acc: 0.9673 - val_mean_iou: 0.6763
# Epoch 67/100
# 722/722 [==============================] - 732s 1s/step - loss: 0.3317 - acc: 0.9800 - mean_iou: 0.7607 - val_loss: 0.4014 - val_acc: 0.9682 - val_mean_iou: 0.6772
# Epoch 68/100
# 722/722 [==============================] - 623s 863ms/step - loss: 0.3309 - acc: 0.9799 - mean_iou: 0.7605 - val_loss: 0.4027 - val_acc: 0.9672 - val_mean_iou: 0.6693
# Epoch 69/100
# 722/722 [==============================] - 640s 886ms/step - loss: 0.3302 - acc: 0.9802 - mean_iou: 0.7636 - val_loss: 0.4055 - val_acc: 0.9669 - val_mean_iou: 0.6658
# Epoch 70/100
# 722/722 [==============================] - 651s 902ms/step - loss: 0.3280 - acc: 0.9803 - mean_iou: 0.7651 - val_loss: 0.4105 - val_acc: 0.9650 - val_mean_iou: 0.6489
# Epoch 71/100
# 722/722 [==============================] - 624s 864ms/step - loss: 0.3279 - acc: 0.9804 - mean_iou: 0.7649 - val_loss: 0.4061 - val_acc: 0.9660 - val_mean_iou: 0.6599
# Epoch 72/100
# 722/722 [==============================] - 795s 1s/step - loss: 0.3281 - acc: 0.9805 - mean_iou: 0.7646 - val_loss: 0.4073 - val_acc: 0.9667 - val_mean_iou: 0.6579
# Epoch 73/100
# 722/722 [==============================] - 701s 972ms/step - loss: 0.3232 - acc: 0.9807 - mean_iou: 0.7657 - val_loss: 0.4053 - val_acc: 0.9675 - val_mean_iou: 0.6678
# Epoch 74/100
# 722/722 [==============================] - 889s 1s/step - loss: 0.3245 - acc: 0.9808 - mean_iou: 0.7674 - val_loss: 0.4117 - val_acc: 0.9646 - val_mean_iou: 0.6504
# Epoch 75/100
# 722/722 [==============================] - 776s 1s/step - loss: 0.3231 - acc: 0.9808 - mean_iou: 0.7683 - val_loss: 0.4116 - val_acc: 0.9653 - val_mean_iou: 0.6427
# Epoch 76/100
# 722/722 [==============================] - 792s 1s/step - loss: 0.3228 - acc: 0.9809 - mean_iou: 0.7691 - val_loss: 0.4079 - val_acc: 0.9663 - val_mean_iou: 0.6609
# Epoch 77/100
# 722/722 [==============================] - 793s 1s/step - loss: 0.3228 - acc: 0.9809 - mean_iou: 0.7666 - val_loss: 0.4078 - val_acc: 0.9662 - val_mean_iou: 0.6614
# Epoch 78/100
# 722/722 [==============================] - 766s 1s/step - loss: 0.3205 - acc: 0.9810 - mean_iou: 0.7686 - val_loss: 0.4088 - val_acc: 0.9663 - val_mean_iou: 0.6592
# Epoch 79/100
# 722/722 [==============================] - 730s 1s/step - loss: 0.3219 - acc: 0.9810 - mean_iou: 0.7676 - val_loss: 0.4105 - val_acc: 0.9657 - val_mean_iou: 0.6501
# Epoch 80/100
# 722/722 [==============================] - 706s 978ms/step - loss: 0.3192 - acc: 0.9813 - mean_iou: 0.7697 - val_loss: 0.4130 - val_acc: 0.9647 - val_mean_iou: 0.6466
# Epoch 81/100
# 722/722 [==============================] - 721s 998ms/step - loss: 0.3181 - acc: 0.9813 - mean_iou: 0.7719 - val_loss: 0.4165 - val_acc: 0.9652 - val_mean_iou: 0.6348
# Epoch 82/100
# 722/722 [==============================] - 723s 1s/step - loss: 0.3186 - acc: 0.9814 - mean_iou: 0.7709 - val_loss: 0.4148 - val_acc: 0.9640 - val_mean_iou: 0.6380
# Epoch 83/100
# 722/722 [==============================] - 718s 994ms/step - loss: 0.3177 - acc: 0.9813 - mean_iou: 0.7706 - val_loss: 0.4144 - val_acc: 0.9641 - val_mean_iou: 0.6386
# Epoch 84/100
# 722/722 [==============================] - 713s 988ms/step - loss: 0.3168 - acc: 0.9815 - mean_iou: 0.7759 - val_loss: 0.4149 - val_acc: 0.9640 - val_mean_iou: 0.6417
# Epoch 85/100
# 722/722 [==============================] - 715s 990ms/step - loss: 0.3163 - acc: 0.9816 - mean_iou: 0.7743 - val_loss: 0.4116 - val_acc: 0.9654 - val_mean_iou: 0.6523
# Epoch 86/100
# 722/722 [==============================] - 678s 939ms/step - loss: 0.3161 - acc: 0.9815 - mean_iou: 0.7723 - val_loss: 0.4155 - val_acc: 0.9640 - val_mean_iou: 0.6349
# Epoch 87/100
# 722/722 [==============================] - 655s 907ms/step - loss: 0.3157 - acc: 0.9815 - mean_iou: 0.7719 - val_loss: 0.4150 - val_acc: 0.9643 - val_mean_iou: 0.6411
# Epoch 88/100
# 722/722 [==============================] - 677s 938ms/step - loss: 0.3170 - acc: 0.9816 - mean_iou: 0.7704 - val_loss: 0.4158 - val_acc: 0.9642 - val_mean_iou: 0.6376
# Epoch 89/100
# 722/722 [==============================] - 709s 982ms/step - loss: 0.3150 - acc: 0.9817 - mean_iou: 0.7757 - val_loss: 0.4147 - val_acc: 0.9646 - val_mean_iou: 0.6440
# Epoch 90/100
# 722/722 [==============================] - 694s 961ms/step - loss: 0.3153 - acc: 0.9816 - mean_iou: 0.7754 - val_loss: 0.4139 - val_acc: 0.9651 - val_mean_iou: 0.6463
# Epoch 91/100
# 722/722 [==============================] - 711s 985ms/step - loss: 0.3154 - acc: 0.9817 - mean_iou: 0.7758 - val_loss: 0.4142 - val_acc: 0.9646 - val_mean_iou: 0.6432
# Epoch 92/100
# 722/722 [==============================] - 828s 1s/step - loss: 0.3155 - acc: 0.9816 - mean_iou: 0.7684 - val_loss: 0.4157 - val_acc: 0.9641 - val_mean_iou: 0.6403
# Epoch 93/100
# 722/722 [==============================] - 717s 993ms/step - loss: 0.3129 - acc: 0.9818 - mean_iou: 0.7754 - val_loss: 0.4148 - val_acc: 0.9644 - val_mean_iou: 0.6447
# Epoch 94/100
# 722/722 [==============================] - 712s 986ms/step - loss: 0.3138 - acc: 0.9817 - mean_iou: 0.7741 - val_loss: 0.4136 - val_acc: 0.9648 - val_mean_iou: 0.6468
# Epoch 95/100
# 722/722 [==============================] - 817s 1s/step - loss: 0.3122 - acc: 0.9818 - mean_iou: 0.7748 - val_loss: 0.4152 - val_acc: 0.9644 - val_mean_iou: 0.6449
# Epoch 96/100
# 722/722 [==============================] - 715s 990ms/step - loss: 0.3154 - acc: 0.9817 - mean_iou: 0.7721 - val_loss: 0.4183 - val_acc: 0.9636 - val_mean_iou: 0.6375
# Epoch 97/100
# 722/722 [==============================] - 718s 995ms/step - loss: 0.3142 - acc: 0.9818 - mean_iou: 0.7729 - val_loss: 0.4158 - val_acc: 0.9641 - val_mean_iou: 0.6428
# Epoch 98/100
# 722/722 [==============================] - 820s 1s/step - loss: 0.3144 - acc: 0.9817 - mean_iou: 0.7717 - val_loss: 0.4147 - val_acc: 0.9646 - val_mean_iou: 0.6442
# Epoch 99/100
# 722/722 [==============================] - 711s 985ms/step - loss: 0.3132 - acc: 0.9818 - mean_iou: 0.7761 - val_loss: 0.4163 - val_acc: 0.9643 - val_mean_iou: 0.6417
# Epoch 100/100
# 722/722 [==============================] - 697s 965ms/step - loss: 0.3129 - acc: 0.9818 - mean_iou: 0.7744 - val_loss: 0.4129 - val_acc: 0.9651 - val_mean_iou: 0.6502

# %%
plt.figure(figsize=(12,4))
plt.subplot(131)
plt.plot(history.epoch, history.history["loss"], label="Train loss")
plt.plot(history.epoch, history.history["val_loss"], label="Valid loss")
plt.legend()
plt.subplot(132)
plt.plot(history.epoch, history.history["acc"], label="Train accuracy")
plt.plot(history.epoch, history.history["val_acc"], label="Valid accuracy")
plt.legend()
plt.subplot(133)
plt.plot(history.epoch, history.history["mean_iou"], label="Train iou")
plt.plot(history.epoch, history.history["val_mean_iou"], label="Valid iou")
plt.legend()
plt.show()

# %% [markdown]
# # Predict test images

# %%
# load and shuffle filenames
folder = './input/rsna-pneumonia-detection-challenge/stage_1_test_images'
test_filenames = os.listdir(folder)
print('n test samples:', len(test_filenames))

# create test generator with predict flag set to True
test_gen = generator(folder, test_filenames, None, batch_size=20, image_size=256, shuffle=False, predict=True)

# create submission dictionary
submission_dict = {}
# loop through testset
for imgs, filenames in test_gen:
    # predict batch of images
    preds = model.predict(imgs)
    # loop through batch
    for pred, filename in zip(preds, filenames):
        # resize predicted mask
        pred = resize(pred, (1024, 1024), mode='reflect')
        # threshold predicted mask
        comp = pred[:, :, 0] > 0.5
        # apply connected components
        comp = measure.label(comp)
        # apply bounding boxes
        predictionString = ''
        for region in measure.regionprops(comp):
            # retrieve x, y, height and width
            y, x, y2, x2 = region.bbox
            height = y2 - y
            width = x2 - x
            # proxy for confidence score
            conf = np.mean(pred[y:y+height, x:x+width])
            # add to predictionString
            predictionString += str(conf) + ' ' + str(x) + ' ' + str(y) + ' ' + str(width) + ' ' + str(height) + ' '
        # add filename and predictionString to dictionary
        filename = filename.split('.')[0]
        submission_dict[filename] = predictionString
    # stop if we've got them all
    if len(submission_dict) >= len(test_filenames):
        break

# save dictionary as csv file
sub = pd.DataFrame.from_dict(submission_dict,orient='index')
sub.index.names = ['patientId']
sub.columns = ['PredictionString']
sub.to_csv('submission.csv')
# Out:
# n test samples: 1000

# %%
#Save Model
# serialize model to JSON
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk
